# %% [markdown]
# # Day-1: 파이썬 기초

# %% [markdown]
# # 1.기본자료형과 변수
# 이 장에서는 기본 자료형(정수형, 실수형, 문자열)과  변수, 그리고 산술연산자를 이용하여 수식을 표현하는 방법을 알아본다.

# %% [markdown]
# ## 기본 자료형
# 파이썬은 다양한 데이터 타입(자료형, Data Type)을 지원하고 있다.
# **데이터 타입**은 데이터가 가지고 있는 속성을 의미하며, 데이터 타입에 따라 지원하는 연산이 다르다.
# 파이썬이 지원하는 몇 가지 주요 데이터 타입을 알아보고, 그에 따른 연산식을 표현해보자.
# - 숫자형 데이터
#   - 정수형(int)
#   - 실수형(float)
# - 문자열(str)
# - 불(bool): 논리형으로, True 또는 False를 가진다.

# %% [markdown]
# ### 숫자 데이터

# %% [markdown]
# #### 정수형 데이터
# - 정수형 데이터는 소수점이 없는 양의 정수, 음의 정수, 0을 표현하는 자료형이다.

# %% [markdown]
# #### 실수형 데이터
# - 실수형 데이터는 소수점이 포함된 숫자를 표현하는 자료형이다.

# %% [markdown]
# #### 숫자형 연산자(Numeric operators)
#
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------|:----------:|:--------:|
# |`+`|덧셈(Addition)| `2 + 2` |`4`|
# |`-`|뺄셈(Subtraction)| `2.0 - 2.0` | `0.0`|
# |`*`|곱셈(Multiplication)| `2 * 3` | `6`|
# |`/`|나눗셈(Division)|`6 / 3`|`2.0`|
# |`//`|버림나눗셈,몫(Floor division)|`10 // 2`|`5`|
# |`%`|나머지(Remainder)|`3 % 2`|`1`|
# |`**`|제곱(Square)|`2 ** 3`|`8`|

# %% [markdown]
# ## 😄문제. 수식을 코드로 표현해보기
#
# $\frac {10.5 + 2 × 3} {45-3.5}$

# %% [markdown]
# ### 문자열 데이터
# - 문자열 데이터는 문자, 숫자, 기호 등을 작은따옴표나 큰따옴표로 묶어 표현하는 자료형이다.

# %% [markdown]
# - print()는 문자열 또는 연산의 결과를 화면에 출력하라는 함수이다. print()에 문자열을 넣어서 작성해보자.

# %%
print("안녕")

# %%
print("hello")

# %% [markdown]
# - 멀티라인 스트링인 경우, 따옴표를 연속 3개 이어쓴다.

# %%
print("""안녕
반가워
파이썬
""")

# %% [markdown]
# - 문자열은 문자뿐만 아니라 공백, 숫자, 특수문자를 포함할 수 있다.

# %%
print('7 apples, 14 oranges, 3 lemons')
print('2*3=6')
print('10.5 + 2 * 3')

# %% [markdown]
# #### 문자열 연산자(String operators)
#
# 문자열도 +, * 연산자를 사용하는 것이 가능하다. 단, 문자열에서 +연산자는 문자열의 나열을 의미하며, *연산자는 문자열의 반복을 의미한다.
#
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------|:----------:|:--------:|
# |`+`|덧셈(Addition)| `'hello' + 'world'` |`helloworld`|
# |`*`|곱셈(Multiplication)| `'hello' * 3` | `hellohellohello`|

# %%
print('파이썬은' + ' ' + '즐거워! ')

# %%
print( '파이썬은 즐거워! ' * 3 )

# %%
print( 'hello!', '5' )

# %% [markdown]
# ## 변수(Variable)
# - 변수는 데이터를 저장하고 필요할 때 이름을 통해 그 값을 사용할 수 있도록 하는 공간이다.

# %%
r = 10
pi = 3.14
S = pi * (r**2)
print('반지름', r,'의 원의 넓이는 ', S, '입니다.')

# %% [markdown]
# ### 변수에 데이터 저장하기

# %%
num = 100
hello = 'hi!'
print(num, hello)

# %% [markdown]
# # 2.입출력과 타입변환

# %% [markdown]
# ## print()
# print()는 문자열, 변수, 연산의 결과를 표준출력장치인 화면에 출력하는 함수이다.

# %%
print(123)
print('hello')
print(50/9)
print('hello!' + 'sunny')
print('hello!', 'sunny')
name = 'sunny'
print(name)
print('hello! ' + name)

# %% [markdown]
# - 소수점 이하 원하는 자릿수까지만 표현하는 방법을 소개한다.
#   - `round(value, n)` n은 자릿수이다. n을 생략하면 반올림하여 정수로 출력한다.

# %%
print(round(3.141592, 3))
print(round(3.141592))
print(round(3.541592))

# %% [markdown]
# - print() 괄호안에 아무런 내용없다면 한 줄 공백을 출력한다.

# %%
print('Hello')
print( )
print('Nice to meet you')

# %% [markdown]
# - 여러개의 결과를 나열하여 출력하려면 콤마(,)로 구분한다. 콤마는 문자열과 숫자를 나열하여 출력할 때 매우 유용하다. print() 괄호안에 콤마가 있으면 콤마 자리마다 기본으로 한칸 띄어쓰기(공백)가 된다.

# %%
print('내 나이는', 20, '살이야')

# %%
age = 20
print('10년 후의 나이는', age+10, '살이야')

# %% [markdown]
# #### f-string
# f-string은 문자열 포맷팅(string formatting)이다. 문자열 앞에 f를 붙이면 값을 넣어서 문자열을 만들 수 있다.

# %% [markdown]
# - print() 괄호안에 f-string과 함께 사용하면 띄어쓰기, 데이터타입 등을 고민 할 필요없이 수월하게 출력할 수 있다.

# %%
name = "민지"
age = 20
print(f'{name}는 {age}살이야')

# %%
a = 5
b = 10
print(f'Five plus ten is {a + b} and not {2 * (a + b)}.')

# %% [markdown]
# ## input()
#
# input() 함수는 프로그램 실행 중에 표준입력장치인 키보드로부터 데이터를 입력받는 함수이다.

# %%
myName = input('Input your name.')
print (f'Welcome, {myName}.')

# %% [markdown]
# input() 함수에는 절대 잊어서는 안될 중요한 특징 하나가 있다. <font color='red'>입력받은 모든 데이터를 문자열로 처리된다는 것이다.</font>

# %%
age = input('나이 입력: ')
print ('10년 후 나이는', age +10, '이네요.')

# %% [markdown]
# ## 😄문제. 밸런스게임
#
#
# <font color='blue'>`test case-1`</font>
# ```
# 요구르트에 김치 말아먹기 vs 라면에 초콜릿 넣기: 라면에 초콜릿 넣기
# 당신은 라면에 초콜릿 넣기를 선택하셨군요!
# ```
#
# <font color='blue'>`test case-2`</font>
# ```
# 요구르트에 김치 말아먹기 vs 라면에 초콜릿 넣기: 둘 다 싫어
# 당신은 둘 다 싫어를 선택하셨군요!
# ```

# %% [markdown]
# ## Data type 확인과 변환
#
# **형 변환**은 데이터의 타입을 변환하는 것으로, 형 변환이 필요한 이유는 데이터가 어떤 타입이냐에 따라 지원하는 연산도 다르기 때문이다. 예를 들어, input() 함수로 입력 받은 데이터는 문자열로 처리되는데 입력 받은 데이터와 숫자 연산을 하려면 데이터의  타입을 정수형 또는 실수형으로 변환해주어야 한다.

# %% [markdown]
# ### int()
# 파이썬에서는 다양한 형 변환 함수를 제공한다.
# int()는 정수로 변환해주는 함수이다.

# %%
print(int('42'))

# %%
age = input('나이 입력: ')
age = int(age)
print ('10년 후 나이는', age +10, '이네요.')

# %% [markdown]
# int()함수는 정수모양이 아닌 문자열은 변환하지 못한다. 예를 들어, '3.5'나 'forty-two'를 변환하려고 하면 에러를 발생시킨다.
#
#
# ```python
# print(int('3.5'))
# print(int('forty-two'))
# ```

# %% [markdown]
# ### float()
# float()은 실수형으로 변환해주는 함수이다. int()와 달리 제약이 없다.

# %%
print(float(42))
print(float('3'))
print(float('3.6'))

# %% [markdown]
# ### str()
# str()은 문자열로 변환해주는 함수이다. 이 또한 제약이 없다.

# %%
print(str(42))
print(str(3.5))

# %% [markdown]
# ## 😄문제. 입력받아 연산하여 출력하기
# 두 개의 정수를 입력 받아 덧셈 연산을 실행한 후에, 연산 결과를 화면에 출력하는 프로그램을 작성하시오.
#
# <font color='blue'>`test case-1`</font>
# ```
# 첫 번째 정수를 입력하세요: 100
# 두 번째 정수를 입력하세요: 200
#
# 100+200의 결과는 300입니다.
# ```
#
# <font color='blue'>`test case-2`</font>
# ```
# 첫 번째 정수를 입력하세요: 300
# 두 번째 정수를 입력하세요: 500
#
# 300+500의 결과는 800입니다.
# ```

# %% [markdown]
# ## 😄문제. 온도변환 프로그램
# 온도를 입력받아 계산한 후 출력하는 프로그램을 작성하시오.
#
# 섭씨온도공식 = 5/9*(화씨온도-32.0)
#
# 화씨온도공식 = 9/5*섭씨온도+32.0
#
# <font color='blue'>`test case-1`</font>
# ```
# 온도 변환 프로그램
# 화씨 온도를 입력하세요: 50
# 섭씨 온도는 10.0 입니다.
#
# 섭씨 온도를 입력하세요: 50
# 화씨 온도는 122.0 입니다.
# ```

# %% [markdown]
# # 3.조건문

# %% [markdown]
# ## 비교연산자
#
# 비교연산자는 정수, 문자열, 변수 등의 값을 비교할 때 사용한다. <font color='red'> 비교연산자의 결과는 bool 타입인 True 또는 False로 나온다. </font>
#
# 비교연산자의 종류는 다음과 같다.

# %% [markdown]
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------:|:----------:|:--------:|
# |`>`|크다|`2 > 1`|`True`|
# |`<`|작다|`2 < 1`|`False`|
# |`>=`|크거나 같다|`2 >= 1`|`True`|
# |`<=`|작거나 같다|`2 <= 1`|`False`|
# |`==`|같다|`1 == '1'`|`False`|
# |`!=`|같지 않다|`1 != '1'`|`True`|

# %%
a=10
b=7
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)

# %%
print('HELLO'=='hello')
print('HELLO'=='Hello')
c='hello'
d='HELLO'
print(c == d)

# %% [markdown]
# ## 멤버연산자
#
# 멤버연산자는 어떤 값이 포함되어 있는지 아닌지를 검사하는 연산자이다. 멤버연산자의 결과는 항상 True 또는 False로 나온다.

# %% [markdown]
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------:|:----------:|:--------:|
# |`in`|포함되어 있다|`'p' in 'python'`|`True`|
# |`not in`|포함되어 있지 않다|`'p' not in 'python'`|`False`|

# %%
print('y' in 'yellow')
print('a' not in 'animal')

# %% [markdown]
# ## 논리 연산자
# 한개 또는 두개 이상의 조건을 비교하여 논리적인 결과를 얻고자 할때 사용한다. 논리연산자의 결과는 항상 True 또는 False로 나온다.

# %% [markdown]
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------:|:----------:|:--------:|
# |`and`|논리곱(그리고)|`True and False`|`False`|
# |`or`|논리합(또는)|`True or False`|`True`|
# |`not`|논리부정(아니다)|`not False`|`True`|

# %% [markdown]
# - 아래의 코드는 논리연산자의 사용을 보여주는 예이다.

# %%
a=10
b=7
c=5
print(a>b and b>c)
print(a>b or b<c)
print(not a>b)

# %% [markdown]
# ## if statements

# %% [markdown]
# ### if 문
# - 비교해야 할 조건식이 하나라면 if문으로 충분하다.

# %%
score = 75
if score >= 75:
  print("success!")

# %% [markdown]
# ### if ~ else 문

# %%
score = 75
if score >= 75:
  print("success!")
else:
  print("Fail!")

# %% [markdown]
# ##😄 입력받아 비교하기
#
# 문제. 입력받은 점수가 80점 이상이면 'Pass!', 80점 미만이면 'Fail!'을 출력하는 코드를 작성하세요.
# ^^^
#
# <font color='blue'>`test case-1`</font>
# ```
# 점수: 90
# Pass!
# ```
# <font color='blue'>`test case-2`</font>
# ```
# 점수: 70
# Fail!
# ```

# %% [markdown]
# ### if ~ elif ~ else 문(다중 if문)

# %%
score= int(input('점수: '))
if score>=90:
  print("당신의 성적은 A입니다.")
elif score>=80:
  print("당신의 성적인 B입니다.")
elif score>=70:
  print("당신의 성적인 C입니다.")
else:
  print("당신의 성적인 F입니다.")

# %% [markdown]
# ## 😄 BMI 계산 프로그램
# 신장(cm)과 체중(kg)을 입력 받아 아래 BMI(신체질량지수) 공식을 이용하여 BMI를 계산하는 프로그램을 작성하시오. BMI가 25이상이면 비만입니다. * BMI 공식의 단위에 주의하세요. weight(kg), height(m)
#
# ---
#
# $ BMI = weight / height^2 $
#
# <font color='blue'>`test case-1`</font>
#
# ```
# 신장(cm): 160
# 체중(kg): 65.2
# BMI는 25.47
# 비만입니다. 운동으로 감량이 필요합니다.
# ```
# <font color='blue'>`test case-2`</font>
#
# ```
# 신장(cm): 170
# 체중(kg): 55.3
# BMI는 19.13
# 정상입니다. 꾸준한 운동으로 유지시켜주세요.
# ```
