# %% [markdown]
# # Chapter-6. 딕셔너리

# %% [markdown]
# ## 😄 딕셔너리 생성
# 아래 key와 value를 딕셔너리 sugang_dict로 만드시오.
#
# |key|value|
# |:----------:|:----------|
# |가수| 아이유, BTS, 뉴진스, 블랙핑크 |
# |배우| 박서준, 임시완, 정해인 |

# %% [markdown]
# ## 😄 딕셔너리 접근1
# 앞에서 만든 딕셔너리 sugang_dict의 가수를 출력하시오.

# %% [markdown]
# ## 😄 딕셔너리 접근2
# 앞에서 만든 딕셔너리 sugang_dict의 배우의 값의 인덱스 2의 데이터를 출력하시오.

# %% [markdown]
# ## 😄 딕셔너리 값 추가
# 앞에서 만든 딕셔너리 sugang_dict에 아래 key와 value를 추가하시오.
#
# |key|value|
# |:----------:|:----------|
# |선수| 손흥민, 류현진, 박지성, 김연아|

# %% [markdown]
# ## 😄 딕셔너리 값 추가
# 앞에서 만든 딕셔너리 sugang_dict의 가수의 값에 '임영웅'을 추가하고 확인하시오.

# %% [markdown]
# ## 😄 반복하여 딕셔너리 값 추가
# 수강생 명단 sugang 리스트와 학번 stdid 리스트가 주어졌을 때, '이름:학번'에 대하여 딕셔너리를 만드시오.
#
# ```
# sugang = ['muzi', 'con', 'apeach', 'jay-G', 'frodo', 'neo', 'tube', 'ryan', 'choonsik']
# stdid = ['2023-23345', '2023-23346', '2023-23347', '2023-23348', '2023-23349', '2023-23350', '2023-23351', '2023-23352', '2023-23353']
# ```
# ```
# Output: {'muzi': '2023-23345', 'con': '2023-23346', 'apeach': '2023-23347', 'jay-G': '2023-23348', 'frodo': '2023-23349', 'neo': '2023-23350', 'tube': '2023-23351', 'ryan': '2023-23352', 'choonsik': '2023-23353'}
# ```

# %% [markdown]
# ## 😄 딕셔너리 활용 칼로리 계산기
# 딕셔너리 sports에는 운동종목과 대사당량이 딕셔너리 형태로 들어가 있습니다. 체중(자연수, kg), 운동시간(자연수, 분), 운동종목을 입력받아 칼로리를 계산하여 출력하는 함수 calorie()를 정의하시오. 입출력은 함수안에서 이루어지며 반환은 없습니다.
#
# ```
# sports = {'걷기': 4, '조깅': 7, '계단오르기': 5, '수영': 9}
# 칼로리 =((METs * 3.5 * 체중(kg)) /200)*운동시간(분)
# ```
# <font color='blue'>`test case-1`</font>
# ---
# Input Sample
# ```
# 60
# 10
# 수영
# ```
# Output Sample
# ```
# 체중(kg):
# 운동시간(m):
# ['걷기', '조깅', '계단오르기', '수영']
# 운동종목:
# 수영 10분은 94.5kcal 소모
# ```
# <font color='blue'>`test case-2`</font>
# ---
# Input Sample
# ```
# 60
# 10
# 요가
# ```
# Output Sample
# ```
# 체중(kg):
# 운동시간(m):
# ['걷기', '조깅', '계단오르기', '수영']
# 운동종목:
# 포함되지 않은 운동종목입니다.
# ```

# %% [markdown]
# ## 😄 The game of death (술게임)
# 'The game of death' 게임에서 최종적으로 술을 마셔야하는 사람을 출력해봅시다.
# 게임이 시작할 때 각 사람과 지목하고 있는 사람의 정보가 딕셔너리 형태로 주어집니다.
# 그리고 랜덤으로 시작하는 사람과 특정 숫자를 입력받습니다. 그러면 시작하는 사람부터 시작하여 가리켜진 사람에게 넘어가면서 숫자를 하나씩 카운트하며, 카운트하고 있는 숫자가 특정 숫자가 될 때까지 이 과정을 반복합니다. 특정 숫자가 되었을 때 최종적으로 지목된 사람이 술을 마시게 됩니다.
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 홍철
# 6
# ```
#
# Output Sample
# ```
# 시작하는 사람:
# 특정 숫자:
# 술 마실 사람: 길
# ```

# %% [markdown]
# <div align="center"><img src="https://haesunbyun.github.io/common/images/death.png" style="width:500px;"></div>

# %%
dictList={'홍철': '하하', '하하' : '길', '명수': '재석', '재석': '길', '길': '재석'}

# %% [markdown]
# # Chapter-7. 함수

# %% [markdown]
# ### 😄 함수 menu() 정의하고 호출하기
# 아래 output sample과 같이 메뉴를 출력하는 함수 menu()를 정의하고 호출해보세요.
# 줄(===)은 '='*70으로 그리세요.
#
# Output Sample
# ```
# ======================================================================
# ['햄에그', 'BLT', '치킨샐러드', '리코다치즈', '런치샌드위치', '미니버거']
# ======================================================================
# ```

# %%
menulist=['햄에그','BLT','치킨샐러드','리코다치즈','런치샌드위치', '미니버거']
# Out:
# ...
# ['햄에그', 'BLT', '치킨샐러드', '리코다치즈', '런치샌드위치', '미니버거']
# ...

# %% [markdown]
# ### 😄 함수 order() 정의하고 호출하기
#
# 메뉴를 입력받아 해당 메뉴의 주문을 확인하는 메시지를 출력하는 order()함수를 정의하고 호출하세요. 메뉴 입력은 함수 밖에서 이루어집니다.
#
# Input Sample
# ```
# 치킨샐러드
# ```
#
# Output Sample
# ```
# ======================================================================
# ['햄에그', 'BLT', '치킨샐러드', '리코타치즈', '런치샌드위치', '미니버거']
# ======================================================================
# 메뉴를 선택해주세요: 치킨샐러드
# 당신은 치킨샐러드를 주문하셨습니다.
# ```

# %%
menulist=['햄에그','BLT','치킨샐러드','리코타치즈','런치샌드위치', '미니버거']

def menu():
  print('='*70)
  print(menulist)
  print('='*70)

# order() 함수 정의
def

menu()
inputOrder = input('메뉴를 선택해주세요: ')

# order() 함수 호출
# Out:
# ...
# ['햄에그', 'BLT', '치킨샐러드', '리코다치즈', '런치샌드위치', '미니버거']
# ...
# 메뉴를 선택해주세요.치킨샐러드
# 당신은 치킨샐러드를 선택하셨습니다.

# %% [markdown]
# ### 😄 mypow() 정의하고 호출하기
# 정수 두개 x,y를 전달받아 $x^y$를 반환하는 mypow() 함수를 정의하시오.
#
# Input Sample
# ```
# 5
# 2
# ```
#
# Output Sample
# ```
# 25
# ```

# %%
#함수 정의
def

#함수 호출
x = int(input('First num: '))
y = int(input('Second num: '))
mypow(x,y)

# %% [markdown]
# ### 😄 pw_check()함수 만들기
#
# 사용자가 입력한 비밀번호가 "pythonisfun!"과 같은지 판별하는 pw_check()함수를 정의하시오. 입력과 출력은 함수 밖에서 이루어지며, 결과는 True, False로 반환합니다.
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# pythoniseasy!
# ```
#
# Output Sample
# ```
# Input password:
# False
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# pythonisfun!
# ```
#
# Output Sample
# ```
# Input password:
# True
# ```

# %% [markdown]
# ### Problem: Dragon realm
# 😄 드래곤을 만났습니다. 당신은 드래곤과 싸워야 합니다.
#
# - 당신은 총 6번 공격할 수 있습니다.
# - Dragon의 초기 체력은 100입니다.
# - 당신의 공격력은 1~30사이의 숫자 중 무작위로 선택된 하나의 값이며 그 값만큼 Dragon의 체력을 소진시킬 수 있습니다.
# - Dragon의 체력이 0 이하가 되면 6번 공격을 채우지 않았어도 공격을 멈춰야 하며 당신은 승리자가 됩니다.
# - 6번의 공격 이후 Dragon의 체력이 0 이하이면 당신은 승리자가 되지만, 0보다 크면 당신은 Dragon에게 잡아 먹히게 됩니다.
#
# ```
# import dragon
# dragon.gameStart()
# ```

# %%
import dragon
dragon.gameStart()

# %% [markdown]
# ### (함께) intro() 함수 만들기
# 😄 아래의 코드를 intro()함수로 만들고 호출해주세요. 한 줄 한 줄 출력될때 마다 시간차를 1초씩 줍니다. 시간차를 주기 위해서는 time 모듈을 불러와야 합니다. 일반적으로 import 코드는 함수정의 파트에 포함시키지 않고 함수 밖에 써줍니다. 전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# You are in a land full of dragons.
# In front of you, you see two caves.
# In one cave, the dragon is friendly,
# and will share his treasure with you.
# The other dragon is greedy and hungry,
# and will eat you on sight.
# ```

# %%
import time
time.sleep(1)
print('You are in a land full of dragons.')
time.sleep(1)
print('In front of you, you see two caves.')
time.sleep(1)
print('In one cave, the dragon is friendly,')
time.sleep(1)
print('and will share his treasure with you.')
time.sleep(1)
print('The other dragon is greedy and hungry,')
time.sleep(1)
print('and will eat you on sight.')

# %% [markdown]
# ### (스스로) intro2() 함수 만들기
# 😄 아래의 코드를 intro2()함수로 만들고 호출해주세요. 한줄 출력시 시간차는 1초로 줍니다.전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# You approach the cave...
# It is dark and spooky...
# A large dragon jumps out in front of you!
# He opens his jaws and...
# ```

# %%
print('You approach the cave...')
time.sleep(1)
print('It is dark and spooky...')
time.sleep(1)
print('A large dragon jumps out in front of you!')
time.sleep(1)
print('He opens his jaws and...')

# %% [markdown]
# ### (스스로) dragon_treasure() 함수 만들기
# 😄 아래의 코드를 dragon_treasure()함수로 만들고 호출해주세요. 전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# Gives you his treasure!
# 그림생략...
# ```

# %%
print('Gives you his treasure!')
print('''
                        __/>^^^;:,'
        .    \'    ,      /-.       :,/|/|'
        _______     __/ ^         :,/ \__'
    _ ./_|___|_\. _(~             ;/ /  /'
        \ \   / /    `-\'--._       / / ,<  ___'
        \ \' \' /   ,__.   /=\     /  _/  >|_\'.'
            \ " /     `_ `--------\'    __ / \',\ \\'
            \./   ,_// ,---_____,   ,_  \_  ,| |'
            V     `--\' |=|           \._/ ,/  |'
                        \=\            `,,/   |'
                        \=\            ||    /'
                            \=\____       |\    \\'
                            / \/    `     <__)    \\'
                            | |                    |'
                        ,__\,\                   /'
                        ,--____>    /\.         ./'
                        \'-__________>  \.______/'
    ''')

# %% [markdown]
# ### (스스로) dragon_fire() 함수 만들기
# 😄 아래의 코드를 dragon_fire()함수로 만들고 호출해주세요. 전달인자와 반환은 없습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# Fire breathing dragon!!!!
# 그림생략...
# ```

# %%
print('Fire breathing dragon!!!!')
print('''
        (  )   /\   _                 (    '
        \ |  (  \ ( \.(               )                      _____'
        \  \ \  `  `   ) \             (  ___                 / _   \\'
        (_`    \+   . x  ( .\            \/   \____-----------/ (o)   \_'
    - .-               \+  ;          (  O                           \____'
                                )        \_____________  `              \  /'
    (__                +- .( -\'.- <. - _  VVVVVVV VV V\                 \/'
    (_____            ._._: <_ - <- _  (--  _AAAAAAA__A_/                  |'
        .    /./.+-  . .- /  +--  - .     \______________//_              \_______'
        (__ \' /x  / x _/ (                                  \___\'          \     /'
        , x / ( \'  . / .  /                                      |           \   /'
        /  /  _/ /    +                                      /              \/'
        \'  (__/                                             /                  \\'
    ''')

# %% [markdown]
# ### (함께) ChooseCave() 함수 만들기
# 😄 동굴 번호 1번과 2번 중에 하나를 입력받습니다. 입력값이 1 또는 2가 아니면 올바른 값을 입력 할 때까지 계속되는 ChooseCave() 함수를 정의하세요. 입력은 함수 내에서, 출력은 함수 밖에서 이루어집니다. 전달인자는 없고 올바른 값이 입력되었다면 입력받은 번호(cave)를 반환합니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 3
# 4
# hello
# 1
# ```
# Output Sample
# ```
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# You chose the number 1.
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 100
# 2
# ```
# Output Sample
# ```
# Which cave will you go into?(1 or 2):
# Which cave will you go into?(1 or 2):
# You chose the number 2.
# ```

# %%
#Todo



cave = ChooseCave()
print(f'You chose the number {cave}.')

# %% [markdown]
# ### (함께) CheckCave() 함수 만들기
# 😄 ChooseCave()에서 반환받은 cave번호가 랜덤 수와 같으면 dragon_treasure() 함수를 호출하고, 다르면 dragon_fire()함수를 호출하는 CheckCave() 함수를 정의하시오. 전달인자는 ChooseCave()에서 반환받은 cave번호이며, 반환값은 없습니다. 랜덤수는 1과 2에서 랜덤하게 생성됩니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Output Sample
# ```
# Fire breathing dragon!!!!
# 그림생략...
# ```
# <font color='blue'>`test case-2`</font>
#
# Output Sample
# ```
# Gives you his treasure!
# 그림생략...
# ```

# %%
#Todo



cave = ChooseCave()
CheckCave(cave)

# %% [markdown]
# ### (스스로) replayGame() 함수 만들기
# 😄 입력값이 'yes', 'Yes', 'y', 'Y', 'YES' 중 하나라면 True를, 하나도 포함되지 않았다면 False를 <font color="red">반환</font>하는  replayGame() 함수를 정의하세요.
# 입력은 함수 안에서 받습니다.
#
# ---
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# yes
# ```
# Output Sample
# ```
# Do you want to play again?(yes or no):
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# No
# ```
# Output Sample
# ```
# Do you want to play again?(yes or no):
# ```

# %%
#Todo


if not replayGame():
  print('Thank you!')

# %% [markdown]
# ### (함께) gameStart() 함수
# 😄 앞에서 정의했던 함수들을 게임 순서대로 호출하고 전체 dragon realm게임을 완성하여 gameStart() 함수를 만드시오.

# %%
import time
import random

while True:

  # 1. intro()함수 호출


  # 2. ChooseCave()함수 호출하여 반환받은 값을 변수 cave에 저장


  # 3. intro2()함수 호출


  # 4. CheckCave()를 호출하면서 변수 cave를 전달인자로 전달


  # 5. replayGame()를 호출하여 반환받은 값에 따라 프로그램 종료 혹은 계속
