# %% [markdown]
# # Day-2: ChatGPT 활용

# %% [markdown]
# # ChatGPT 질문하기와 응용하기

# %% [markdown]
# <font color="red">Q</font>. 인공지능의 역사에 대해서 알려줘

# %% [markdown]
# <font color="red">Q</font>. 인공지능에 대해 개론적인 설명을 해줘

# %% [markdown]
# <font color="red">Q</font>. 위의 내용을 기반으로 인공지능에 대한 객관식 문제를 3개 만들어줘

# %% [markdown]
# <font color="red">Q</font>. 인공지능에 대한 설명을 1000자 내외로 설명해줘

# %% [markdown]
# ## 값 계산하기
# - 아래 값에 대해 계산한 후 최종적으로 표로 생성

# %% [markdown]
# <font color="red">Q</font>. 아래 표에서 각 학생들의 평균과 과목별 평균점수를 계산해줘. 그리고 학생들의 점수와 평균, 과목별 평균점수, 전체과목 평균를 표로 만들어줘
# ```
# 김혜미 국어 80 영어 85 수학 75
# 박중수 국어 95 영어 75 수학 90
# 최민희 국어 100 영어 85 수학 75
# 황희수 국어 100 영어 95 수학 85
# ```

# %% [markdown]
# <font color="red">Q</font>. 가상의 한국 학생 100명을 만들어 각 학생의 국어 영어 수학 성적을 70~100점 사이로 만들어줘
#
# 각 학생의 평균과 각 과목의 평균을 계산한 후 전체 내용을 엑셀표로 만들어줘

# %% [markdown]
# <font color="Blue">Problem</font>. 1부터 100 사이의 소수를 찾고 그 소수들의 총합, 산술평균, 기하평균을 계산한 표를 작성해보세요.

# %% [markdown]
# - 코드가 생성되면 실행시켜본 후 검증해본다.
# - <font color="red">Q</font>. 1부터 100까지 소수를 알려줘
# - <font color="red">Q</font>. 위 소수의 총 합을 계산해줘
# - <font color="red">Q</font>. 위 소수의 산술평균과 기하평균을 수식과 함께 알려줘

# %% [markdown]
# ## 엑셀의 함수 사용하기

# %% [markdown]
#  <font color="red">Q</font>. 차례대로 번호, 이름, 전화번호로 20명의 가상 데이터를 만들어줘.
# 이름은 한글이름으로 해주고 전화번호는 총 11자리로 만들어줘
# <div align="center"><img src="https://haesunbyun.github.io/common/images/gptPic3.PNG" width="200"></div>

# %% [markdown]
# # ChatGPT를 활용한 파이썬 기초

# %% [markdown]
# # I. 기본자료형과 변수
# 이 장에서는 기본 자료형(정수형, 실수형, 문자열)과  변수, 그리고 산술연산자를 이용하여 수식을 표현하는 방법을 알아본다.

# %% [markdown]
# ## 기본 자료형
# 파이썬은 다양한 데이터 타입(자료형, Data Type)을 지원하고 있다.
# **데이터 타입**은 데이터가 가지고 있는 속성을 의미하며, 데이터 타입에 따라 지원하는 연산이 다르다.
# 파이썬이 지원하는 몇 가지 주요 데이터 타입을 알아보고, 그에 따른 연산식을 표현해보자.
# - 숫자형 데이터
#   - 정수형(int)
#   - 실수형(float)
# - 문자열(str)
# - 불(bool): 논리형으로, True 또는 False를 가진다.
# - None: 값이 없음을 의미하며, '아무것도 반환하지 않은' 함수의 반환 값이다.

# %% [markdown]
# ### 숫자 데이터

# %% [markdown]
# #### 정수형 데이터

# %%
123456789012345678901234567890 * 1234556677

# %%
4434567788884344431667886553 - 3354565631156734333583729667788999900

# %% [markdown]
# #### 실수형 데이터

# %% [markdown]
# - 소수점 표현 방식의 유효한 자리수 한계를 확인해보자. 소수점 17자리에서 반올림되어 소수점 16자리까지 표현되는 것을 확인할 수 있다.

# %%
1.12345678901234567890123456789

# %% [markdown]
# - **지수 표현 방식**에서 지수(Exponential)는 로마자 *E* 또는 *e*로 표기하는데 과학이나 공학에서 아주 큰 숫자를 간단하게 표기할 때 사용하며, 의미는 10^이다.
# 예를들어, 지수 표현 방식으로 1.23e+5은 $1.23 * 10^5$이며, 123000.0과 같다. 1.23e-4는 $1.23 * 10^{-4}$이며 0.000123과 같다.
# 지수 표현 방식에서도 유효한 자리수의 한계를 넘어가면 inf(infinity)로 나온다.

# %%
1.23e+5

# %%
1.23e-4

# %%
1.23e+309

# %% [markdown]
# #### 숫자형 연산자(Numeric operators)
#
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------|:----------:|:--------:|
# |`+`|덧셈(Addition)| `2 + 2` |`4`|
# |`-`|뺄셈(Subtraction)| `2.0 - 2.0` | `0.0`|
# |`*`|곱셈(Multiplication)| `2 * 3` | `6`|
# |`/`|나눗셈(Division)|`6 / 3`|`2.0`|
# |`//`|버림나눗셈,몫(Floor division)|`10 // 2`|`5`|
# |`%`|나머지(Remainder)|`3 % 2`|`1`|
# |`**`|제곱(Square)|`2 ** 3`|`8`|

# %% [markdown]
# ### 문자열 데이터

# %% [markdown]
# - print()는 문자열 또는 연산의 결과를 화면에 출력하라는 함수이다. print()에 문자열을 넣어서 작성해보자.

# %%
print('hello')

# %%
print("Hello World")

# %%
print('파이썬은 재밌어')

# %% [markdown]
# - 멀티라인 스트링인 경우, print()에 문자열을 넣어서 출력할 수 있다.

# %%
print("""안녕
반가워
파이썬
""")

# %% [markdown]
# - 문자열은 문자뿐만 아니라 공백, 숫자, 특수문자를 포함할 수 있다.

# %%
print('7 apples, 14 oranges, 3 lemons')

# %%
print('O*&#wY%*&OCfsdYO*& gfC%YO')

# %% [markdown]
# - 홑따옴표(')나 쌍따옴표(")기호가 모두 들어가 있을 때에는 고민할 필요없이 멀티라인 스트링으로 써준다.

# %%
print('''그녀는 '블랙홀'을 생각하면서 "충치가 깊네요" 라고 말했다.''' )

# %% [markdown]
# #### 문자열 연산자(String operators)
#
# 문자열도 +, * 연산자를 사용하는 것이 가능하다. 단, 문자열에서 +연산자는 문자열의 나열을 의미하며, *연산자는 문자열의 반복을 의미한다.
#
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------|:----------:|:--------:|
# |`+`|덧셈(Addition)| `'hello' + 'world'` |`helloworld`|
# |`*`|곱셈(Multiplication)| `'hello' * 3` | `hellohellohello`|

# %%
print('파이썬은' + ' ' + '즐거워! ')

# %%
print( '파이썬은 즐거워! ' * 3 )

# %%
print( 'hello!' + 5 )

# %% [markdown]
# ## 변수(Variable)
#
# 숫자가 숫자로만 존재하거나, 문자가 문자로만 남아있다면 활용성이 떨어진다. 프로그래밍에서는 숫자, 문자 등의 값(value)를 변수에 저장해 놓으면 훨씬 활용성을 높일 수 있다.
#
# **변수**란 값을 저장하기 위한 이름을 가진 저장공간이며, **대입 연산자** 기호인 =를 이용하여 값을 저장한다.

# %%
r = 10
pi = 3.14
S = pi * (r**2)
print('반지름', r,'의 원의 넓이는 ', S, '입니다.')

# %% [markdown]
# **예약어**란 파이썬에서 내장되어 이미 사용하기로 정의된 키워드를 의미한다. 참고로 아래 코드를 통해 파이썬의 예약어와 개수를 확인해보자.

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))

# %% [markdown]
# 파이썬에는 미리 기능을 만들어 놓은 내장함수들, 클래스들이 매우 많다.(예, print(), input(), str(), int(), ...)
# - 간혹 내장함수명이나 클래스명을 변수명으로 사용하면, 예를들어
#   * print='hello'
#   * input=input()
#   * str='hello'
# str(42) 등과 같이 작성하면 기존에 정의된 기능이 동작하지 않게 된다.

# %% [markdown]
# ### 변수에 데이터 저장하기
#
# 변수에 값을 저장해보자. 이를 프로그래밍에서는 변수에 값을 **할당한다**라고 말한다.
# 변수에 값을 할당하려면 대입연산자 기호인 =를 기준으로 왼쪽에는 변수명, 오른쪽에는 값 또는 표현식을 적는다.

# %%
num = 100
hello = 'hi!'
print(num, hello)

# %% [markdown]
# :::{admonition} 주의!
# :class: warning
#
# 초보자의 경우, 변수명과 문자열에 익숙하지 않아 변수명에 문자열 처리를 하는 실수를 범하기도 한다.
#
# ```
# name = 'sun'
# print('name')
# ```
# 이와 같이 코드를 작성했다면, 변수 name에 저장되어 있는 'sun'이 출력되는 것이 아니라 'name'이라는 문자열 자체가 출력된다.
# 변수 name과 문자열 'name'은 서로 다르다는 것에 주의하자.
# :::

# %%
name = 'sun'
print('name')

# %%
name = "young"
print(name)

# %%
spam = 100
print(spam+200)

# %%
spam = 15
spam = spam + 5
print(spam)

# %% [markdown]
# ## I. ChatGPT 활용 연습문제

# %% [markdown]
# ## 😄문제. 수식을 코드로 표현해보기
#
# $\frac {10.5 + 2 × 3} {45-3.5}$

# %% [markdown]
# ## 😄문제. 다음 내용을 코드로 작성하시오.
#
# - 변수 insa에 'Hello!'를 저장하시오.
# - 변수 name에 본인 이름을 영어로 저장하시오.
# - Hello! 본인 이름이 나오게 출력하시오. (예: Hello!Alice)
# - Hello! 본인 이름 사이에 공백을 추가해서 출력하시오. (예: Hello! Alice)

# %% [markdown]
# ## 😄문제. 변수활용하여 수식으로 표현해보기
#
# x는 3이다. 변수 x를 활용하여 수식을 작성해보고 y를 출력하시오.
#
#
# $ y=[\{(𝑥^2−2𝑥)−6\}×2]+(3𝑥−3)÷2 $

# %% [markdown]
# ## 😄문제. 문자열 표현해보기
#
# 변수 name에 '지수'를 넣고 변수를 활용하여 3번 연속으로 '지수야 반가워'를 출력하시오.
#
# Output Sample
# ```
# 지수야 반가워 지수야 반가워 지수야 반가워
# ```

# %% [markdown]
# # II. 입출력과 타입변환

# %% [markdown]
# ## print()
# print()는 문자열, 변수, 연산의 결과를 표준출력장치인 화면에 출력하는 함수이다.

# %%
print(123)
print('hello')
print(50/9)
print('hello! ' + 'sunny')
print('hello! ''sunny')
name = 'sunny'
print(name)
print('hello! ' + name)

# %% [markdown]
# :::{admonition} Tip
# :class: tip
#
# - 소수점 이하 원하는 자릿수까지만 표현하는 방법을 소개한다.
#   - `round(value, n)` n은 자릿수이다. n을 생략하면 반올림하여 정수로 출력한다.
#   :::

# %%
print(round(3.141592, 3))
print(round(3.141592))
print(round(3.541592))

# %% [markdown]
# - print() 괄호안에 아무런 내용없다면 한 줄 공백을 출력한다.

# %%
print('Hello')
print( )
print('Nice to meet you')

# %% [markdown]
# - 여러개의 결과를 나열하여 출력하려면 콤마(,)로 구분한다. 콤마는 문자열과 숫자를 나열하여 출력할 때 매우 유용하다. print() 괄호안에 콤마가 있으면 콤마 자리마다 기본으로 한칸 띄어쓰기(공백)가 된다.

# %%
print('내 나이는', 20, '살이야')

# %%
age = 20
print('10년 후의 나이는', age+10, '살이야')

# %% [markdown]
# #### f-string
# f-string은 문자열 포맷팅(string formatting)이다. 문자열 앞에 f를 붙이면 값을 넣어서 문자열을 만들 수 있다.

# %% [markdown]
# - print() 괄호안에 f-string과 함께 사용하면 띄어쓰기, 데이터타입 등을 고민 할 필요없이 수월하게 출력할 수 있다.

# %%
name = "민지"
age = 20
print(f'{name}는 {age}살이야')

# %%
a = 5
b = 10
print(f'Five plus ten is {a + b} and not {2 * (a + b)}.')

# %% [markdown]
# ### ChatGPT 활용 연습문제

# %% [markdown]
# 😄문제. 변수를 활용하여 아래와 같은 결과가 나오도록 코드를 작성해 보세요. '딱!' 문자열이 age+number만큼 출력되어야 합니다.
# ^^^
#
# ```python
# a = '딱!'
# age = 21
# number = 10
# # TODO
# ```
# Output:
#
# 10년후에, 너의 나이는 딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱!딱! 31살이 될꺼야.

# %% [markdown]
# ## input()
#
# input() 함수는 프로그램 실행 중에 표준입력장치인 키보드로부터 데이터를 입력받는 함수이다.

# %%
print ('Input your name.')
myName = input()
print (f'Welcome, {myName}.')

# %%
myName = input('Input your name.')
print (f'Welcome, {myName}.')

# %% [markdown]
# input() 함수에는 절대 잊어서는 안될 중요한 특징 하나가 있다. <font color='red'>입력받은 모든 데이터를 문자열로 처리된다는 것이다.</font>

# %%
age = input('How old are you? ')
print ('You are '  + age + ' years old.')

# %% [markdown]
# ### ChatGPT 활용 연습문제

# %% [markdown]
# 😄문제. 다음과 같이 출력결과가 나오도록 코드를 작성해 보세요.
#
#
# <font color='blue'>`test case-1`</font>
# ```
# 요구르트에 김치 말아먹기 vs 라면에 초콜릿 넣기: 라면에 초콜릿 넣기
# 당신은 라면에 초콜릿 넣기를 선택하셨군요!
# ```
#
# <font color='blue'>`test case-2`</font>
# ```
# 요구르트에 김치 말아먹기 vs 라면에 초콜릿 넣기: 둘 다 싫어
# 당신은 둘 다 싫어를 선택하셨군요!
# ```

# %% [markdown]
# ## Data type 확인과 변환
#
# **형 변환**은 데이터의 타입을 변환하는 것으로, 형 변환이 필요한 이유는 데이터가 어떤 타입이냐에 따라 지원하는 연산도 다르기 때문이다. 예를 들어, input() 함수로 입력 받은 데이터는 문자열로 처리되는데 입력 받은 데이터와 숫자 연산을 하려면 데이터의  타입을 정수형 또는 실수형으로 변환해주어야 한다.

# %% [markdown]
# ### int()
# 파이썬에서는 다양한 형 변환 함수를 제공한다.
# int()는 정수로 변환해주는 함수이다.

# %%
print(int(42))
print(int(3.5))
print(int('42'))
print(int('    42   '))

# %% [markdown]
# :::{admonition} 참고
# :class: warning
#
# int()함수는 정수모양이 아닌 문자열은 변환하지 못한다. 예를 들어, '3.5'나 'forty-two'를 변환하려고 하면 에러를 발생시킨다.
#
#
# ```python
# print(int('3.5'))
# print(int('forty-two'))
# ```
# :::

# %% [markdown]
# ### float()
# float()은 실수형으로 변환해주는 함수이다. int()와 달리 제약이 없다.

# %%
print(float(42))
print(float(3.5))
print(float('3'))
print(float('3.6'))

# %% [markdown]
# ### str()
# str()은 문자열로 변환해주는 함수이다. 이 또한 제약이 없다.

# %%
print(str(42))
print(str(3.5))
print(str('42'))
print(str('3.5'))

# %% [markdown]
# ### ChatGPT 활용 연습문제

# %% [markdown]
# ## 😄문제. 입력값 출력하기
# 두 개의 정수를 입력 받아 덧셈 연산을 실행한 후에, 연산 결과를 화면에 출력하는 프로그램을 작성하시오.
#
# <font color='blue'>`test case-1`</font>
# ```
# 첫 번째 정수를 입력하세요: 100
# 두 번째 정수를 입력하세요: 200
#
# 100+200의 결과는 300입니다.
# ```
#
# <font color='blue'>`test case-2`</font>
# ```
# 첫 번째 정수를 입력하세요: 300
# 두 번째 정수를 입력하세요: 500
#
# 300+500의 결과는 800입니다.
# ```

# %% [markdown]
# ## 😄문제. 온도변환 프로그램
# 온도를 입력받아 계산한 후 출력하는 프로그램을 작성하시오.
#
# 섭씨온도공식 = 5/9*(화씨온도-32.0)
#
# 화씨온도공식 = 9/5*섭씨온도+32.0
#
# <font color='blue'>`test case-1`</font>
# ```
# 온도 변환 프로그램
# 화씨 온도를 입력하세요: 50
# 섭씨 온도는 10.0 입니다.
#
# 섭씨 온도를 입력하세요: 50
# 화씨 온도는 122.0 입니다.
# ```

# %% [markdown]
# # III. 조건문

# %% [markdown]
# ## Sample Source Code #1

# %%
# This is a guess the number game.
myName = input('Hello! What is your name?')
number = 5
print ( 'Well, ' + myName + ', I am thinking of a number between 1 and 20.')

guess = int(input('Take a guess.'))

if guess != number:
  print ( 'Your guess is wrong.')
if guess == number:
  print ( 'Good job, ' + myName + '! You guessed my number!')

# %% [markdown]
# ## 비교연산자
#
# 비교연산자는 정수, 문자열, 변수 등의 값을 비교할 때 사용한다. <font color='red'> 비교연산자의 결과는 항상 bool 타입인 True 또는 False로 나온다. </font>
#
# 비교연산자의 종류는 다음과 같다.

# %% [markdown]
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------:|:----------:|:--------:|
# |`>`|크다|`2 > 1`|`True`|
# |`<`|작다|`2 < 1`|`False`|
# |`>=`|크거나 같다|`2 >= 1`|`True`|
# |`<=`|작거나 같다|`2 <= 1`|`False`|
# |`==`|같다|`1 == '1'`|`False`|
# |`!=`|같지 않다|`1 != '1'`|`True`|

# %%
a=10
b=7
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)

# %%
print('HELLO'=='hello')
print('HELLO'=='Hello')
c='hello'
d='HELLO'
print(c == d)

# %% [markdown]
# - 한글도 비교가 가능하다.
# - 한글은 자음, 모음 각각 unicode가 부여되어 있다.
# - 유니코드 값 확인은 ord() 함수를 통해 가능하다.
# - 반대로 유니코드 값으로 문자를 확인하는 함수로는 chr() 함수가 있다.

# %%
print('가', ord('가'))
print('ㄱ', ord('ㄱ'))
print('a', ord('a'))
print('A', ord('A'))
print('1', ord('1'))
print('9', ord('9'))

# %% [markdown]
# :::{admonition} 숫자 모양의 문자 비교 시 주의
# :class: warning
#
# 가끔 입력받은 값의 형 변환을 하지 않아 숫자 모양의 문자를 숫자인줄 알고 비교하는 경우가 있다. 이러한 경우 에러가 발생하지 않고 숫자 모양의 문자 유니코드 값을 비교하니 주의하자.
# :::

# %%
print('12'< '123')

# %%
print('123' > '93')

# %% [markdown]
# - 숫자와 문자는 당연히 같지 않으므로 같다, 같지않다 비교했을 때 비교결과가 나온다.

# %%
print(5 == '5')
print(5 != '5')

# %% [markdown]
# ## 멤버연산자
#
# 멤버연산자는 어떤 값이 포함되어 있는지 아닌지를 검사하는 연산자이다. 멤버연산자의 결과는 항상 True 또는 False로 나온다.

# %% [markdown]
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------:|:----------:|:--------:|
# |`in`|포함되어 있다|`'p' in 'python'`|`True`|
# |`not in`|포함되어 있지 않다|`'p' not in 'python'`|`False`|

# %%
print('y' in 'yellow')
print('a' not in 'animal')

# %% [markdown]
# ## 논리 연산자
# 한개 또는 두개 이상의 조건을 비교하여 논리적인 결과를 얻고자 할때 사용한다. 논리연산자의 결과는 항상 True 또는 False로 나온다.

# %% [markdown]
# |연산 기호|의미|예시|실행 결과|
# |:----------:|:----------:|:----------:|:--------:|
# |`and`|논리곱(그리고)|`True and False`|`False`|
# |`or`|논리합(또는)|`True or False`|`True`|
# |`not`|논리부정(아니다)|`not False`|`True`|

# %% [markdown]
# - 아래의 코드는 논리연산자의 사용을 보여주는 예이다.

# %%
a=10
b=7
c=5
print(a>b and b>c)
print(a>b or b<c)
print(not a>b)

# %% [markdown]
# - 논리연산자는 not > and > or로 우선순위를 가진다. 우선순위가 동일한 경우에는 왼쪽에서 오른쪽 순서로 실행한다.

# %%
print(not False or True and False or True )

# %% [markdown]
# :::{admonition} Short Circuit Effect
# :class: warning
#
# `Short circuit 효과는 짧게 짧게 전기가 흐른다는 뜻`으로 프로그래밍에서는 어떤 경우에는 정상적으로 실행하고 어떤 경우에는 에러가 나오는 경우를 의미한다.
# 프로그램의 크기가 크고 복잡한 경우에는 이러한 원인을 파악하기 어렵게 만들기도 한다.

# %%
a=10
b=7
print(a>b or 1/0)

# %%
i=10
print(i%2 != 0 and muyaho == 0)

# %% [markdown]
# ## if statements
#
# if문은 조건에 따라 실행을 분기시키는 문으로 if문, if ~ else문, if ~ elif ~ else문이 있다.
# - 조건식의 끝에는 반드시 콜론(:)을 붙여야 한다.
# - 조건식에 변수가 들어간다면 반드시 미리 정의되어 있어야 한다.
# - 조건에 의해서 실행되는 문장들은 반드시 들여쓰기(Indentation)을 해야 한다.

# %% [markdown]
# ### if 문
# - 비교해야 할 조건식이 하나라면 if문으로 충분하다.

# %%
score = 75
if score >= 75:
  print("success!")

# %% [markdown]
# 😄문제. 입력받은 점수가 80점 이상이면 'Pass!'를 출력하는 코드를 작성하세요.
#
# <font color='blue'>`test case-1`</font>
# ```
# 점수: 90
# Pass!
# ```
# <font color='blue'>`test case-2`</font>
# ```
# 점수: 70
# ```

# %% [markdown]
# ### if ~ else 문
# - 비교해야 할 조건식이 True일때와 False일때를 분기하여 실행해야 한다면 if ~ else문이 적합하다.
# - 아래 코드에서 print('Happy')는 조건에 의해 실행되는 문장이 아니다. 따라서 들여쓰기가 되어 있지 않다.

# %%
state = 'Hit'
if state == 'Hit':
  print("Homerun!")
else:
  print("Strike!")

print("Happy")

# %% [markdown]
# ### if ~ elif ~ else 문(다중 if문)

# %%
a=10
b=7
c=3
query=5
if query>a:
  print("가장 큰 수 이다.")
elif query>b:
  print("두 번째로 큰 수 이다.")
elif query>c:
  print("세 번째로 큰 수 이다.")
else: #없을수도 있음
  print("가장 작은 수 이다.")

print('End')

# %% [markdown]
# :::{grid} 1
# :::{grid-item-card}
# :class-header: bg-light
#
# 😄문제. 변수 number와 같은 수, 큰 수, 작은 수를 출력하고 싶었다. 무엇이 문제인지 찾아보시오.
# ^^^
#
# ```python
# number = 75
# if number == 75:
#   print ( '같다.')
# if number > 75:
#   print ( '크다.')
# else:
#   print('작다.')
# ```

# %% [markdown]
# ## 모듈과 모듈 불러오기
# **모듈**은 서로 관련있는 함수들을 모아 놓은 집합이다.

# %%
import random
random.randint(1, 100)

# %% [markdown]
# ### ChatGPT 활용 연습문제

# %% [markdown]
# ## Sample Source Code #2
#
# 😄 다음 코드를 아래의 세가지 조건으로 실행되도록 비교파트를 수정해보세요.
#
# - (조건1) guess가 number보다 크면 'Your guess is high.'
# - (조건2) guess가 number보다 작으면 'Your guess is low.'
# - (조건3) guess와 number가 같으면 지금 메시지 그대로
#
#
# ```python
# # This is a guess the number game.
# myName = input('Hello! What is your name?')
# number = 5
# print ( 'Well, ' + myName + ', I am thinking of a number between 1 and 20.')
#
# guess = int(input('Take a guess.'))
#
# if guess != number:
#  print ( 'Your guess is wrong.')
# if guess == number:
#  print ( 'Good job, ' + myName + '! You guessed my number!')
# ```

# %% [markdown]
# ## Sample Source Code #3
#
# 😄 number의 값을 랜덤수로 수정하세요.
#
# - TODO-1: number = 5 대신에 1부터 20 사이의 랜덤 수를 number에 저장하세요.
# - TODO-2: Sample Source Code #2에서 여러분이 작성한 비교파트 코드를 #TODO-2 아래에 넣어주세요.
#
# ```python
# # This is a guess the number game.
# myName = input('Hello! What is your name?')
# number = 5
# print ( 'Well, ' + myName + ', I am thinking of a number between 1 and 20.')
#
# guess = int(input('Take a guess.'))
#
# # TODO-2
#
# ```

# %% [markdown]
# ##BMI 계산 프로그램
# 😄신장(cm)과 체중(kg)을 입력 받아 아래 BMI(신체질량지수) 공식을 이용하여 BMI를 계산하는 프로그램을 작성하시오. BMI가 25이상이면 비만입니다. * 단위에 주의하세요.
#
# ---
#
# ```
# weight(kg)
# height(m)
#
# ```
# $ BMI = weight / height^2 $
#
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 160
# 65.2
# ```
# Output Sample
# ```
# 신장(cm):
# 체중(kg):
# BMI는 25.47
# 비만입니다. 운동으로 감량이 필요합니다.
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 170
# 55.3
# ```
# Output Sample
# ```
# 신장(cm):
# 체중(kg):
# BMI는 19.13
# 정상입니다. 꾸준한 운동으로 유지시켜주세요.
# ```

# %% [markdown]
# ## 합격, 불합격, 과락 판단
# 😄이름과 국어, 수학, 컴퓨터 점수(정수) 세 개를 입력받아 다음 조건에 따라 결과를 출력하는 프로그램을 작성하시오.
#
# - 합격: 평균이 60점 이상이고 모두 40점 이상
# - 과락: 평균이 60점 이상이나 40점 미만 과목이 있음
# - 불합격: 평균이 60점 미만
#
# ---
#
# <font color='blue'>`test case-1`</font>
#
# Input Sample
# ```
# 홍길동
# 87
# 37
# 77
# ```
# Output Sample
# ```
# 이름:
# 국어:
# 수학:
# 컴퓨터:
# 홍길동님은 과락입니다.
# ```
# <font color='blue'>`test case-2`</font>
#
# Input Sample
# ```
# 홍길동
# 87
# 57
# 77
# ```
# Output Sample
# ```
# 이름:
# 국어:
# 수학:
# 컴퓨터:
# 홍길동님은 합격입니다.
# ```
# <font color='blue'>`test case-3`</font>
#
# Input Sample
# ```
# 홍길동
# 62
# 37
# 68
# ```
# Output Sample
# ```
# 이름:
# 국어:
# 수학:
# 컴퓨터:
# 홍길동님은 불합격입니다.
# ```
